# %%
from agent import graph

state = graph.invoke({"messages": [{"role": "user", "content": "Who won the euro 2024"}], "max_research_loops": 3, "initial_search_query_count": 3})

# %%
state
# Out:
# {'messages': [HumanMessage(content='Who won the euro 2024', additional_kwargs={}, response_metadata={}, id='4b0ccc12-2e74-4a55-a85e-c512e7867c26'),
# ...

# %%
from IPython.display import Markdown

Markdown(state["messages"][-1].content)
# Out:
# Spain won the UEFA Euro 2024 tournament [youtube](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGFcidniPKtBR-_QjSR1P1Oathq_0T9FTwfpCAWZxbXsroItHQU8zRcyOPDgMcvsWoD2fEnwYFKwanV18ep2_cyS5BlHF6-OFNsijWb-peAgsgLAVRiubekRnzMugsYtiWrhZyO3Q==) [aljazeera](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEk7ApC7Y41UOrTWJ40wP2rsT0VDxqhqF-WJEI-FNKW7SNpR7LoA22sRQecS8hZNeZ_-62Vh7X75RmcmZUtnAOuQunrLAsETkkSx5l75dt9ESgTRkIURwtu4Pew7hn8yFz_LY_FJXUpmRfoWP7MWrDfPHcKrOpfmKqONj6mJcASNvAfCZ0p6qK3K4PvKWye6NyBMyYxWCuJig==) [foxsports](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHh_4hBL0Giyuw_cyfT8m7tUSnMqBqH4Lis1CtJICPJNGGLhT6PADTIoUtrj3Rl5qcKNE9T6rzOmedAER_gxJOBDrCF8pnr9lUvhYvmDJxYCJzELkE5rTap4dx6FzOIKZKm1QBp5aHXzd_LCkSTV9ag7Q1A6_t8Vjdbskch6ZG3BoIfjYDQSPgRKDNFAAwt5J07cVFV5pDQzggmM7pxwsUz4drz) [wikipedia](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXGd9ZQky3X7RQLbTs6mY1i4Pg7ppcI5H_vtxpvQPiEyD8Qw0f7hjvn3QeoOeAVcCG_pEt
# ...

# %%
state = graph.invoke({"messages": state["messages"] + [{"role": "user", "content": "How has the most titles? List the top 5"}]})

# %%
Markdown(state["messages"][-1].content)
# Out:
# Based on the number of UEFA European Championship titles won, Spain holds the record [olympics](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXHoAXOG7_3DUjYvRr_buN8IAL3xE5yQoPetZCb1KlcaMOgJEE5BeBoqQEVVkDZLDpwgTmFkPYeWS7i_D23Vd5bKzUTfc0HSLI481VbXjMD9ECeZRFZ17g3xAYLg5I0QU34RWLCRcV_zgphUsJZ0L5gXjpYz5gl8syuYAX3VkHCwh0x6Wqau4er_cZ56CoiA-3S_r2I=) [sportsadda](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXEYq2a0benYn0vF2WrfvmqEsgwriQ08aVcDdpS1MUjBxlzaV_scV0ldVeUpwqcgVLCfxgX3oVmbUxbkFPzeHbknsAbxLFk4Iyvtxgacx54AZBnL1szGQ9cQQGOOT8f-zGZhzKWEhAIOYTsz89uAr55R546MlC31OFXiU7AGhMgLi0Ekk6wQvPJVTWs_TiaG4MHoHo0obaRhJK1iPYaAxqHKD2Zf5rTr2jmdPBPd9w==) [wikipedia](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXG_0rXuWu0vsaIzCzaUG9Rw0L65I3o3RWhCp4gzXiHDZW3GaJXLntEQNi-O88mGf5LlE0tAkMNd_5VBNOkzIxAkbVsdkpPjwtzuY1sjv2gjtHLnvbIa8Y9jFbdS8kE3xqj95_TayzxNWpyr-XkwY9qLW4NI) [yahoo](https://vertexaisearch.cloud.google.com/grounding-api-redirect/AbF9wXE
# ...

# %%
from agent.graph import (
    generate_query,
    continue_to_web_research,
    web_research,
    reflection, 
    evaluate_research,
    finalize_answer
)

from agent.state import (
    OverallState,
)

import os

from dotenv import load_dotenv
from langgraph.types import Send
from langgraph.graph import StateGraph
from langgraph.graph import START, END
from langchain_core.runnables import RunnableConfig
from google.genai import Client
from agent.configuration import Configuration
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

if os.getenv("GEMINI_API_KEY") is None:
    raise ValueError("GEMINI_API_KEY is not set")

# Used for Google Search API
genai_client = Client(api_key=os.getenv("GEMINI_API_KEY"))

# %%
from agent.prompts import (
    company_extraction_instructions,
    people_extraction_instructions
)
from agent.utils import get_research_topic
from agent.tools_and_schemas import ExtractionResult
from agent.state import CompanyExtractionState, ExtractPeopleDetailsState

# %%
def extract_companies(state: OverallState, config: RunnableConfig) -> CompanyExtractionState:
  """Langgraph node that extracts companies from the final summary result.
  
  Processes the summaries to extract structured business entities including comapnies, investment amount, associated people and location.
  Uses the configure LLM to perform with high accuracy.
  
  Args:
      state: Current graph state containing the running summary and sources gathered
      config: Configuration for the runnable, including LLM provider settings
  
  Returns:
      Dictionary with state update, including running_summary key containing list of ExtractionResult objects
      """
      
  configurable = Configuration.from_runnable_config(config)
  reasoning_model = state.get("reasoning_model") or configurable.reflection_model

  formatted_prompt = company_extraction_instructions.format(
      research_topic=get_research_topic(state["messages"]),
      summaries="\n---\n\n".join(state["messages"][-1].content),
  )

  # init Reasoning Model
  llm = ChatGoogleGenerativeAI(
      model=reasoning_model,
      temperature=0,
      max_retries=2,
      api_key=os.getenv("GEMINI_API_KEY"),
  )

  structured_llm = llm.with_structured_output(ExtractionResult)

  # Run the LLM
  results =  structured_llm.invoke(formatted_prompt)
  
  company_list = list(company.company_name for company in results.entities)
  
  return {
      "companies": [results],
      "company_list": company_list
  }

# %%
def continue_to_find_people(state: CompanyExtractionState):
    """LangGraph node that sends the comapny search queries to the find_people node.

    This is used to spawn n number of find_people nodes, one for each company."""
    
    return [
        Send("find_people", {"company": company, "id": int(idx)})
             for idx, company in enumerate(state["company_list"])
    ]

# %%
def find_people(state: ExtractPeopleDetailsState, config:RunnableConfig) -> OverallState:
    """LangGraph node that performs web research using the native Google Search API tool to find people/decision-makers associated with the company.

    Executes a web search using the native Google Search API tool in combination with Gemini 2.0 Flash.

    Args:
        state: Current graph state containing the company_name and research loop count
        config: Configuration for the runnable, including search API settings

    Returns:
        Dictionary with state update, including sources_gathered, research_loop_count, and web_research_results"""
        
    configurable = Configuration.from_runnable_config(config)
    
    formatted_prompt = people_extraction_instructions.format(
        company_name=state["company"],
    )
    
    response = genai_client.models.generate_content(
        model=configurable.answer_model,
        contents=formatted_prompt,
        config={
            "tools": [{"google_search": {}}],
            "temperature": 0,
        },
    )
    
    return {
        "people_details": [{
            "company": state["company"],
            "results": response
        }]
    }

# %%
# Create our Agent Graph
builder = StateGraph(OverallState, config_schema=Configuration)

# Define the nodes we will cycle between
builder.add_node("generate_query", generate_query)
builder.add_node("web_research", web_research)
builder.add_node("reflection", reflection)
builder.add_node("finalize_answer", finalize_answer)
builder.add_node("extract_companies", extract_companies)
builder.add_node("find_people", find_people)

# Set the entrypoint as `generate_query`
# This means that this node is the first one called
builder.add_edge(START, "generate_query")
# Add conditional edge to continue with search queries in a parallel branch
builder.add_conditional_edges(
    "generate_query", continue_to_web_research, ["web_research"]
)
# Reflect on the web research
builder.add_edge("web_research", "reflection")
# Evaluate the research
builder.add_conditional_edges(
    "reflection", evaluate_research, ["web_research", "finalize_answer"]
)
# Finalize the answer
builder.add_edge("finalize_answer", "extract_companies")
builder.add_conditional_edges("extract_companies", continue_to_find_people, ["find_people"])
builder.add_edge("find_people", END)

# builder.compile(name="pro-search-agent")
graph = builder.compile(name="pro-search-agent")

# %%
state = graph.invoke({"messages": [{"role": "user", 
                                    "content": "What global companies are planning to setup their offices as global capability centers in India?"}], "max_research_loops": 6, "initial_search_query_count": 3})
# Out:
# FINAL RESPONSE:  sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Following a comprehensive search for real estate and facilities management decision-makers at HSBC in India, here are the key individuals identified:
#
# ### Real Estate & Corporate Real Estate
#
# *   **Samir Patil** holds the position of **Head of Corporate Real Estate** at HSBC Software Development (India) Pvt. Ltd. He manages a significant 1.2 million square feet portfolio of corporate real estate across India, encompassing six offices in Pune and Hyderabad. His responsibilities include real estate strategy, transactions, capital projects, and facility management.
# ...

# %%
from IPython.display import Markdown

Markdown(state["messages"][-1].content)
# Out:
# As of July 2025, India is a premier destination for global companies establishing Global Capability Centers (GCCs), with two to three new centers launching every week [sansovi](https://vertexaisearch.cloud.google.com/id/2-0). These hubs have evolved from cost-saving operations to strategic centers for innovation and digital transformation [krtya](https://vertexaisearch.cloud.google.com/id/0-0).
#
# Several global companies have recently announced plans or have just opened new GCCs in India:
#
# *   **Costco:** The retail giant plans to establish its first GCC in India in the city of Hyderabad, initially creating over 1,000 jobs [sansovi](https://vertexaisearch.cloud.google.com/id/2-0).
# *   **Citizens Financial:** The American bank has opened a new center in Hyderabad, with plans to build a workforce of approximately 1,000 employees [sansovi](https://vertexaisearch.cloud.google.com/id/2-0).
# ...

# %%
print(type( state['people_details']))
# Out:
# <class 'list'>

# %%
def print_response(response):
    res = {
        "text": "",
        "grounding_metadata": [],
        "grounding_supports": [],
        "web_search_queries": []
    }
    
    res["text"] = response.content.parts[0].text
    
    for i, chunk in enumerate(response.grounding_metadata.grounding_chunks):
        res["grounding_metadata"].append({
            "title": chunk.web.title,
            "uri": chunk.web.uri,
        })
    for j, chunk in enumerate(response.grounding_metadata.grounding_supports):
        res["grounding_supports"].append({
            "text": chunk.segment.text
        })
    for k, query in enumerate(response.grounding_metadata.web_search_queries):
        res["web_search_queries"].append(query)
    return res

# %%
import pandas as pd

result = []
for i, people_in_company in enumerate(state['people_details']):
    # print(f"Company {i + 1}:")
    res = print_response(people_in_company.candidates[0])
    result.append(res)
    
df = pd.DataFrame(result)
df
# Out:
#                                                  text  \
# 0   Based on the current search results, Costco's ...
# 1   Based on the research, there are no specific k...
# 2   Based on the research conducted, specific indi...
# 3   Following a comprehensive search for key real ...
# 4   Following a detailed investigation into the ke...
# 5   Following a detailed investigation into the re...
# 6   Following a detailed investigation into the ke...
# 7   Following a comprehensive investigation into t...
# 8   As an expert research assistant, I have identi...
# 9   As an expert research assistant, I have identi...
# 10  Following a comprehensive search for real esta...
# 11  Here are the key decision-makers in real estat...
# 12  Based on the research, here are the key decisi...
# 13  Based on the research conducted, here are the ...
# 14  Following a detailed investigation into the re...
# 15  As an expert research assistant, I have identi...
# ...

# %%
# for i, people_in_company in enumerate(state['people_details']):
people_in_company = state['people_details'][5]
print(f"Company {i + 1}:")
print("TEXT CONTENT: ", people_in_company.candidates[0].content.parts[0].text)
print("GROUNDING METADATA: \n")
for i, chunk in enumerate(people_in_company.candidates[0].grounding_metadata.grounding_chunks):
    print(f"Chunk {i + 1}:")
    print("TITLE: ", chunk.web.title)
    print("URL: ", chunk.web.uri)
print("GROUNDING SUPPORTS: \n")
for j, chunk in enumerate(people_in_company.candidates[0].grounding_metadata.grounding_supports):
    print(f"Chunk {j + 1}:")
    print("TITLE: ", chunk.segment.text)
print("WEB SEARCH QUERIES: \n")
for k, query in enumerate(people_in_company.candidates[0].grounding_metadata.web_search_queries):
    print(f"Query {k + 1}: {query}")
# print(people_in_company.candidates[0].grounding_metadata)
print("\n\n")
    # parse_gemini_response_to_json(people_in_company)
# Out:
# Company 6:
# TEXT CONTENT:  Following a detailed investigation into the real estate and facilities management leadership at JPMorgan in India, several key individuals have been identified in decision-making roles. The research indicates a significant presence of senior management in these functions within the country.
#
# ### Key Decision Makers at JPMorgan India
#
# **Executive Leadership in Real Estate and Construction:**
#
# *   **Murali B** holds the position of **Executive Director of Global Real Estate (GRE) and India Head of Design & Construction**. In this capacity, he is responsible for managing JPMorgan Chase's extensive real estate portfolio in India. His duties include ensuring that the firm's facilities align with strategic business goals and enhance employee satisfaction. He leads a team dedicated to executing complex, high-value projects, including the design and construction of office campuses and data centers.
#
# **Management in Facilities and Administration:**
#
# ...

# %%
state["people_details"]

for i, people_in_company in enumerate(state['people_details']):
    print(f"Company {i + 1}:")
    for j, person in enumerate(people_in_company.people_details):
        print(f"Person {j + 1}:")
        print(f"Name: {person.person_name}")
        print(f"Job Title: {person.job_title}")
        print(f"Company: {person.company_name}")
        print(f"Experience: {person.experience_years}")
        print(f"Location: {person.location}")
        print(f"LinkedIn Profile: {person.linkedin_profile}")
        print(f"Other Social Profiles: {person.other_social_profiles}")
        print(f"Bio Summary: {person.bio_summary}")
        print(f"Additional Details: {person.additional_details}")
        print("Confidence score:", person.confidence_score)
        print("\n\n")
    print("Extraction notes:", people_in_company.extraction_notes)
    print("Search Query Used: ", people_in_company.search_query_used)
    for k, source in enumerate(people_in_company.source_urls):
        print(f"Source {k + 1}: {source}")
    print("\n\n")
# Out:
# Company 1:
# Person 1:
# Name: Eshwar N
# Job Title: Vice President - Real Estate
# Company: BlackRock
# Experience: None
# Location: None
# LinkedIn Profile: None
# Other Social Profiles: []
# Bio Summary: None
# Additional Details: None
# Confidence score: 0.8
#
#
#
# Person 2:
# Name: Ashish Varma
# Job Title: Head of Real Estate - India, Middle East & SEA
# Company: BlackRock
# Experience: None
# Location: None
# LinkedIn Profile: None
# Other Social Profiles: []
# Bio Summary: None
# Additional Details: None
# Confidence score: 0.8
#
#
#
# Person 3:
# Name: Ritwick Udayan
# Job Title: Director, Real Estate
# Company: BlackRock
# Experience: None
# Location: None
# LinkedIn Profile: None
# Other Social Profiles: []
# Bio Summary: None
# Additional Details: None
# Confidence score: 0.8
#
#
#
# Person 4:
# Name: Bhavin Sanghvi
# Job Title: Vice President, Real Estate
# Company: BlackRock
# Experience: None
# Location: None
# LinkedIn Profile: None
# Other Social Profiles: []
# ...

# %%
state = graph.invoke({"messages": [{"role": "user", "content": "What global companies are planning to setup their offices as global capability centers in India?"}], "max_research_loops": 6, "initial_search_query_count": 3})
# Out:
# RESULTS:  entities=[InvestmentEntity(company_name='Costco', investment_amount=None, associated_people=[], location=Location(city='Hyderabad', state=None, country='India', full_address=None), industry='Retail', additional_details='Establishing a GCC focusing on technology and research operations, with initial plans to hire 1,000 professionals.'), InvestmentEntity(company_name='Daikin', investment_amount=None, associated_people=[], location=Location(city='Gurgaon', state=None, country='India', full_address=None), industry='Air-conditioner manufacturing', additional_details='Set up the "Daikin Innovation and Services Hub" GCC in partnership with EY, focusing on IT, digital services, data management, finance, and AI, with plans to employ around 700 people.'), InvestmentEntity(company_name='Vanguard', investment_amount=None, associated_people=[], location=Location(city='Hyderabad', state=None, country='India', full_address=None), industry='Investment management', additional_details='Chose
# ...

# %%
# import pandas as
# print(json.dumps(state, indent=4))
entities = state['companies'][0].entities

for i, entity in enumerate(entities):
    print(f"Company {i + 1}:")
    print(f"Name: {entity.company_name}")
    print(f"Investment Amount: {entity.investment_amount}")
    print(f"Associated People: {entity.associated_people}")
    print(f"Location: {entity.location}")
    print(f"Industry: {entity.industry}")
    print(f"Additional Details: {entity.additional_details}")
    print("\n\n")
# Out:
# Company 1:
# Name: Costco
# Investment Amount: None
# Associated People: []
# Location: city='Hyderabad' state=None country='India' full_address=None
# Industry: Retail
# Additional Details: Establishing its first Global Capability Center (GCC) focusing on technology and research operations, expected to initially employ 1,000 people.
#
#
#
# Company 2:
# Name: Daikin
# Investment Amount: None
# Associated People: [Person(name='EY', role='Partner', company_affiliation='EY')]
# Location: city='Gurgaon' state=None country='India' full_address=None
# Industry: Air-conditioner manufacturing
# Additional Details: Set up a GCC called the Daikin Innovation and Services Hub, focusing on IT, digital services, finance, and AI, with plans to employ around 700 individuals.
#
#
#
# Company 3:
# Name: Vanguard
# Investment Amount: None
# Associated People: []
# Location: city='Hyderabad' state=None country='India' full_address=None
# Industry: Investment management
# ...
